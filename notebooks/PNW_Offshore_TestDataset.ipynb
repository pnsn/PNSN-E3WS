# %% [markdown]
# # PNSN_Coastal_Dataset_Inspection
# **:auth:** Nathan T. Stevens
# **:email:** ntsteven (at) uw.edu
# **:org:** Pacific Northwest Seismic Network
# **:license:** Creative Commons 4.0-BY
# **:attribution:**
# This notebook is part of a repository building on the `E3WS` repository published by Pablo Lara (Lara et al., 2023) and uses metadata from the Pacific Northwest Seismic Network (Network Code UW). If referencing elements related to `E3WS` please cite Lara et al. (2023)
#
# **:purpose:**
# This notebook documents PNSN catalog event sub-sampling to use for testing `E3WS`'s predictive capabilities on regional events, particularly those that bracket the current PNSN alert triggering threshold (M $\geq$ 2.95).
#
# **:references:**
# Pablo Lara, Quentin Bletery, Jean-Paul Ampuero, Adolfo Inza, Hernando Tavera. Earthquake Early Warning Starting From 3 s of Records on a Single Station With Machine Learning. Journal of Geophysical Research: Solid Earth. https://doi.org/10.1029/2023JB026575

# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# # Define PNSN reporting boundary
# rlatll, rlonll = 41., -129.
# rlatur, rlonur = 51., -116.

# # Define PNSN authoratative boundary (plus a little slop)
# alatll, alonll = 42., -125.5
# alatur, alonur = 49., -117.

# Define Coastal WA/OR Search Box
latll, lonll = 42., -125.5
latur, lonur = 49., -122.

# %%
# Initalize ObsPy Client
client = Client("IRIS")

# %%
# First, do some work to identify offshore events along Cascadia that may be of interest
CSZ_events = os.path.join('..','data','sql_queries','updated_event_origin_query.csv')
df = pd.read_csv(CSZ_events,index_col=[0])
# Do some basic filtering for just earthquakes with positive magnitudes
df = df[(df.magnitude > 0) & (df.etype=='eq')]
# Convert origin times from epoch to DateTime
df.datetime = df.datetime.apply(lambda x:pd.Timestamp(x, unit='s'))
display(df)
# Out:
#          etype   prefor  prefmag  selectflag  version  magnitude magtype  \
# evid
# 60403201    eq  1123038   866953           1        8       2.59       d
# 60404061    eq  1125433   869338           1        8       2.41       d
# 60404206    eq  1125708  2514938           1        9       1.61       l
# 60741056    eq  1678453  1423203           1        6       2.41       d
# 60404291    eq  1125838   869748           1        8       0.91       d
# ...        ...      ...      ...         ...      ...        ...     ...
# 61962896    eq  3242108  3233108           1        5       0.54       d
# 61502808    eq  3242123  3233123           1        4       0.84       d
# 61962871    eq  3242128  3233128           1        5       0.55       d
# 61962866    eq  3242148  3233148           1        7       0.64       d
# 61502803    eq  3242118  3233088           1        6       0.82       d
#
#              magalgo  nsta  nobs  ...  ndef   nbs  nbfm  fdepth  fepi  rflag  \
# evid                              ...
# 60403201   HypoinvMd     2   2.0  ...   6.0   1.0   6.0       y     y      F
# 60404061   HypoinvMd     3   3.0  ...  18.0   3.0  10.0       y     n      F
# 60404206  RichterMl2     7  12.0  ...  21.0  12.0   8.0       n     n      F
# 60741056   HypoinvMd     5   5.0  ...   6.0   1.0   4.0       y     n      F
# 60404291   HypoinvMd     3   3.0  ...  10.0   6.0   4.0       n     n      F
# ...              ...   ...   ...  ...   ...   ...   ...     ...   ...    ...
# 61962896   HypoinvMd     5   5.0  ...   5.0   0.0   0.0       y     n      F
# 61502808   HypoinvMd     4   4.0  ...   5.0   0.0   0.0       y     n      F
# 61962871   HypoinvMd     5   5.0  ...   5.0   0.0   0.0       n     n      F
# 61962866   HypoinvMd     4   4.0  ...   4.0   0.0   0.0       y     y      F
# 61502803   HypoinvMd     3   3.0  ...   5.0   0.0   0.0       y     n      F
#
#           crust_type  crust_model  gtype  auth
# evid
# 60403201           H          NaN      r    UW
# 60404061           H          NaN      r    UW
# 60404206           H          NaN      l    UW
# 60741056           H          NaN      r    UW
# 60404291           H          NaN      l    UW
# ...              ...          ...    ...   ...
# 61962896           H          C3       l    UW
# 61502808           H          C3       l    UW
# 61962871           H          C3       l    UW
# 61962866           H          C3       l    UW
# 61502803           H          C3       l    UW
#
# [3929 rows x 34 columns]

# %%
# Do some additional geographic filtering for identifying temporal clusters of offshore events
df = df[(df.lon < -124.6) & (df.magnitude >= 2)] # chops out coastal events
px.scatter_geo(df[df.magnitude > 2],lat='lat',lon='lon',color='magnitude', hover_data=['datetime','magnitude','magtype'])

# %%
px.histogram(df,'datetime', nbins = 13*12)

# %%
target_window = [pd.Timestamp("2018-08-01"), pd.Timestamp("2019-01-01")]
df2 = df.copy()[(df.datetime >= target_window[0]) &\
                (df.datetime <= target_window[1])]
px.histogram(df2, 'datetime', nbins=100)
px.scatter_geo(df2,lon='lon',lat='lat',color='magnitude')

# %%
# Get a list of stations along the coast that were active during the
CHAN_STR = ""
for _b in "BEH":
    for _i in "HN":
        for _c in "Z3N1E2":
            CHAN_STR += _b + _i + _c
            if _b + _i + _c != 'HN2':
                CHAN_STR += ','

client = Client("IRIS")
inv = client.get_stations(
    network="UW",
    startbefore=UTCDateTime(target_window[0].isoformat()),
    endafter=UTCDateTime(target_window[1].isoformat()),
    minlongitude=-125,
    maxlongitude=-123.25,
    channel=CHAN_STR,
    level="channel",
)
display(inv)
# Out:
# Inventory created at 2023-11-16T22:59:35.425800Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?network=UW&channel=B...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			UW
# 		Stations (46):
# 			UW.BABR (Baber Butte, OR, USA)
# 			UW.BAND (Bandon, OR, USA)
# 			UW.BILS (Queets, WA, USA)
# 			UW.BROK (Brookings, OR, USA)
# 			UW.CABL (Cape Blanco, OR, USA)
# 			UW.CHZZ (Cape Meares, OR, USA)
# 			UW.CNNB (Cannon Beach, OR, USA)
# 			UW.COOS (Coos Bay, OR, USA)
# 			UW.CORE (Aberdeen, WA, USA)
# 			UW.FISH (Jewel, OR, USA)
# 			UW.FLRE (Florence, OR, USA)
# 			UW.FORK (Forks, WA, USA)
# 			UW.HEBO (Mt. Hebo, OR CREST BB SMO)
# 			UW.HURR (Hurricane Ridge, WA, USA)
# 			UW.JEDS (Smith River, Reedsport, OR, USA)
# 			UW.KMO (Kings Mt., Oregon previous ISC code: KMOR)
# 			UW.LEBA (Lebam, WA, USA)
# 			UW.LRIV (Port Angeles, WA, USA)
# 			UW.LWCK (Lewis and Clark Interpretive Center, WA, USA)
# 			UW.MKAH (Makah Indian Reservation, WA, USA)
# 			UW.MPO (Marys Peak, OR, USA)
# 			UW.NEWO (Hatfield Marine Science Center, Newport, OR, USA)
# 			UW.OBC (Olympics - Bonidu Creek)
# 			UW.OCEN (Ocean Shores, WA, USA)
# 			UW.OCP (Cheeka Peak, Olympic Mountains, WA, USA)
# 			UW.ONAB (Ona Beach, OR, USA)
# 			UW.OOW2 (Octopus West, WA, USA)
# 			UW.OSD (Snowdome, Mt Olympus, WA, USA)
# 			UW.OTR (Olympic Penninsula - Tyee Ridge, WA, USA)
# 			UW.PABH (Pacific Beach Navy Resort, WA, USA)
# 			UW.RADR (Radar Ridge, Naselle, WA)
# 			UW.REED (Reedsport, OR, USA)
# 			UW.RNO (Roman Nose, OR, USA)
# 			UW.ROBC (Roos Farm, OR, USA)
# 			UW.RSLG (Rose Lodge, OR, USA)
# 			UW.SEAS (Seaside Museum, Seaside, OR, USA)
# 			UW.SMW (South Mtn., WA, USA)
# 			UW.STW (Striped Peak, Port Angeles, WA, USA)
# 			UW.TAHO (Taholah School, Taholah, WA, USAA)
# 			UW.TAKO (Tahkenitch BPA Substation, OR, USA)
# 			UW.TILL (Tillamook, OR, USA)
# 			UW.TOLO (Toledo BPA Substation, Toledo, OR, USA)
# 			UW.UMPQ (Umpqua Community College, OR, DOGAMI SMO)
# 			UW.WEDR (Wedderburn, OR, USA)
# 			UW.WISH (Wishka, WA, USA)
# 			UW.YACH (Yachats, OR, USA)
# 		Channels (160):
# 			UW.BABR..ENZ, UW.BABR..ENN, UW.BABR..ENE, UW.BABR..HHZ,
# 			UW.BABR..HHN, UW.BABR..HHE, UW.BAND..HNZ, UW.BAND..HNN,
# 			UW.BAND..HNE, UW.BILS..HNZ, UW.BILS..HNN, UW.BILS..HNE,
# 			UW.BROK..HNZ, UW.BROK..HNN, UW.BROK..HNE, UW.CABL..HNZ,
# 			UW.CABL..HNN, UW.CABL..HNE, UW.CHZZ..HNZ, UW.CHZZ..HNN,
# 			UW.CHZZ..HNE, UW.CNNB..HNZ, UW.CNNB..HNN, UW.CNNB..HNE,
# 			UW.COOS..HNZ, UW.COOS..HNN, UW.COOS..HNE, UW.CORE..HNZ,
# 			UW.CORE..HNN, UW.CORE..HNE, UW.FISH..ENZ, UW.FISH..ENN,
# 			UW.FISH..ENE, UW.FISH..HHZ, UW.FISH..HHN, UW.FISH..HHE,
# 			UW.FLRE..HNZ, UW.FLRE..HNN, UW.FLRE..HNE, UW.FORK..BHZ,
# 			UW.FORK..BHN, UW.FORK..BHE, UW.FORK..ENZ, UW.FORK..ENN,
# 			UW.FORK..ENE, UW.HEBO..BHZ, UW.HEBO..BHN, UW.HEBO..BHE,
# 			UW.HEBO..ENZ, UW.HEBO..ENN, UW.HEBO..ENE, UW.HURR..HNZ,
# 			UW.HURR..HNN, UW.HURR..HNE, UW.JEDS..ENZ, UW.JEDS..ENN,
# 			UW.JEDS..ENE, UW.JEDS..HHZ, UW.JEDS..HHN, UW.JEDS..HHE, UW.KMO..EHZ
# 			UW.LEBA..ENZ, UW.LEBA..ENN, UW.LEBA..ENE, UW.LEBA..HHZ,
# 			UW.LEBA..HHN, UW.LEBA..HHE, UW.LRIV..BHZ, UW.LRIV..BHN,
# 			UW.LRIV..BHE, UW.LRIV..ENZ, UW.LRIV..ENN, UW.LRIV..ENE,
# 			UW.LWCK..HNZ, UW.LWCK..HNN, UW.LWCK..HNE, UW.MKAH..HNZ,
# 			UW.MKAH..HNN, UW.MKAH..HNE, UW.MPO..EHZ, UW.MPO..ENZ, UW.MPO..ENN,
# 			UW.MPO..ENE, UW.NEWO..HNZ, UW.NEWO..HNN, UW.NEWO..HNE, UW.OBC..EHZ
# 			UW.OCEN..HNZ, UW.OCEN..HNN, UW.OCEN..HNE, UW.OCP..EHZ,
# 			UW.OCP..ENZ, UW.OCP..ENN, UW.OCP..ENE, UW.ONAB..HNZ, UW.ONAB..HNN,
# 			UW.ONAB..HNE, UW.OOW2..HNZ, UW.OOW2..HNN, UW.OOW2..HNE, UW.OSD..EHZ
# 			UW.OSD..ENZ, UW.OSD..ENN, UW.OSD..ENE, UW.OTR..EHZ, UW.PABH..HNZ
# 			UW.PABH..HNN, UW.PABH..HNE, UW.RADR..BHZ, UW.RADR..BHN,
# 			UW.RADR..BHE, UW.RADR..ENZ, UW.RADR..ENN, UW.RADR..ENE,
# 			UW.REED..HNZ, UW.REED..HNN, UW.REED..HNE, UW.RNO..EHZ, UW.ROBC..HNZ
# 			UW.ROBC..HNN, UW.ROBC..HNE, UW.RSLG..HNZ, UW.RSLG..HNN,
# 			UW.RSLG..HNE, UW.SEAS..HNZ, UW.SEAS..HNN, UW.SEAS..HNE, UW.SMW..EHZ
# 			UW.STW..EHZ, UW.STW..ENZ, UW.STW..ENN, UW.STW..ENE, UW.TAHO..HNZ
# 			UW.TAHO..HNN, UW.TAHO..HNE, UW.TAKO..ENZ, UW.TAKO..ENN,
# 			UW.TAKO..ENE, UW.TILL..HNZ, UW.TILL..HNN, UW.TILL..HNE,
# 			UW.TOLO..ENZ, UW.TOLO..ENN, UW.TOLO..ENE, UW.UMPQ..EHZ,
# 			UW.UMPQ..ENZ, UW.UMPQ..ENN, UW.UMPQ..ENE, UW.WEDR..HNZ,
# 			UW.WEDR..HNN, UW.WEDR..HNE, UW.WISH..BHZ, UW.WISH..BHN,
# 			UW.WISH..BHE, UW.WISH..ENZ, UW.WISH..ENN, UW.WISH..ENE,
# 			UW.YACH..HNZ, UW.YACH..HNN, UW.YACH..HNE

# %%
# Convert inventory into dataframe
holder = []
for _n in inv.networks:
    net = _n.code
    for _s in _n.stations:
        sta = _s.code
        bi_codes = []
        nsc = len(_s.channels)
        if isinstance(_s.termination_date, UTCDateTime):
            termdate = pd.Timestamp(_s.termination_date.isoformat(),unit='s')
        else:
            termdate = pd.NaT
        for _c in _s.channels:
            if _c.code[:2] not in bi_codes:
                bi_codes.append(_c.code[:2])
                ch_count = 0; ch_str = ''
                for _xc in _s.channels:
                    if _xc.code[:2] == _c.code[:2]:
                        ch_count += 1
                        ch_str += _xc.code[-1]
                line = [net, sta, _c.code[:2], ch_str, ch_count, nsc, _s.latitude, _s.longitude, _s.elevation, pd.Timestamp(_s.creation_date.isoformat(),unit='s'), termdate]
                holder.append(line)
df_sta = pd.DataFrame(holder, columns=["Network", "Station", "BandInst", "BIChannels", "nBIChan", 'nSiteChan', "lat", "lon", "elev", 'on_date','off_date'])
display(df_sta.sort_values('on_date'))
px.scatter_geo(df_sta[(df_sta.BandInst.isin(['HH','HN'])) & (df_sta.nSiteChan>=6)],
               lat='lat',lon='lon', color='on_date',
               hover_data=['Network','Station','BandInst','BIChannels','nBIChan','nSiteChan'])
# Out:
#    Network Station BandInst BIChannels  nBIChan  nSiteChan        lat  \
# 48      UW     STW       EH          Z        1          4  48.150669
# 49      UW     STW       EN        ENZ        3          4  48.150669
# 47      UW     SMW       EH          Z        1          1  47.319450
# 32      UW     OCP       EH          Z        1          4  48.297870
# 33      UW     OCP       EN        ENZ        3          4  48.297870
# 30      UW     OBC       EH          Z        1          1  48.035110
# 20      UW     KMO       EH          Z        1          1  45.635330
# 38      UW     OTR       EH          Z        1          1  48.086320
# 36      UW     OSD       EH          Z        1          4  47.816420
# 37      UW     OSD       EN        ENZ        3          4  47.816420
# 28      UW     MPO       EN        ENZ        3          4  44.504280
# 27      UW     MPO       EH          Z        1          4  44.504280
# 43      UW     RNO       EH          Z        1          1  43.916199
# 53      UW    TOLO       EN        ENZ        3          3  44.621610
# 51      UW    TAKO       EN        ENZ        3          3  43.743130
# 15      UW    HEBO       BH        ENZ        3          6  45.213501
# 16      UW    HEBO       EN        ENZ        3          6  45.213501
# 46      UW    SEAS       HN        ENZ        3          3  45.997600
# 58      UW    WISH       EN        ENZ        3          6  47.116980
# 57      UW    WISH       BH        ENZ        3          6  47.116980
# 54      UW    UMPQ       EH          Z        1          4  43.290901
# 55      UW    UMPQ       EN        ENZ        3          4  43.290901
# 10      UW    FISH       EN        ENZ        3          6  45.930600
# 11      UW    FISH       HH        ENZ        3          6  45.930600
# 29      UW    NEWO       HN        ENZ        3          3  44.623920
# 22      UW    LEBA       HH        ENZ        3          6  46.545898
# 21      UW    LEBA       EN        ENZ        3          6  46.545898
# 23      UW    LRIV       BH        ENZ        3          6  48.057500
# 24      UW    LRIV       EN        ENZ        3          6  48.057500
# 14      UW    FORK       EN        ENZ        3          6  47.947500
# 13      UW    FORK       BH        ENZ        3          6  47.947500
# 41      UW    RADR       EN        ENZ        3          6  46.421810
# 40      UW    RADR       BH        ENZ        3          6  46.421810
# 19      UW    JEDS       HH        ENZ        3          6  43.751570
# 18      UW    JEDS       EN        ENZ        3          6  43.751570
# 25      UW    LWCK       HN        ENZ        3          3  46.277800
# 35      UW    OOW2       HN        ENZ        3          3  47.749190
# 31      UW    OCEN       HN        ENZ        3          3  46.952473
# 3       UW    BILS       HN        ENZ        3          3  47.539660
# 50      UW    TAHO       HN        ENZ        3          3  47.344372
# 8       UW    COOS       HN        ENZ        3          3  43.395660
# 12      UW    FLRE       HN        ENZ        3          3  43.988090
# 56      UW    WEDR       HN        ENZ        3          3  42.442000
# 5       UW    CABL       HN        ENZ        3          3  42.836500
# 2       UW    BAND       HN        ENZ        3          3  43.090300
# 44      UW    ROBC       HN        ENZ        3          3  45.309510
# 9       UW    CORE       HN        ENZ        3          3  46.925700
# 59      UW    YACH       HN        ENZ        3          3  44.315000
# 7       UW    CNNB       HN        ENZ        3          3  45.888100
# 4       UW    BROK       HN        ENZ        3          3  42.076700
# 26      UW    MKAH       HN        ENZ        3          3  48.370700
# 6       UW    CHZZ       HN        ENZ        3          3  45.486500
# 45      UW    RSLG       HN        ENZ        3          3  45.022400
# 42      UW    REED       HN        ENZ        3          3  43.701280
# 34      UW    ONAB       HN        ENZ        3          3  44.514660
# 52      UW    TILL       HN        ENZ        3          3  45.454970
# 39      UW    PABH       HN        ENZ        3          3  47.212779
# 17      UW    HURR       HN        ENZ        3          3  47.970350
# 1       UW    BABR       HH        ENZ        3          6  44.621320
# 0       UW    BABR       EN        ENZ        3          6  44.621320
#
#            lon     elev    on_date off_date
# 48 -123.671059   318.40 1973-06-01      NaT
# 49 -123.671059   318.40 1973-06-01      NaT
# 47 -123.344450   877.00 1975-03-01      NaT
# 32 -124.625160   470.00 1980-05-19      NaT
# 33 -124.625160   470.00 1980-05-19      NaT
# 30 -124.078819   938.00 1980-05-29      NaT
# 20 -123.490730   975.00 1982-09-30      NaT
# 38 -124.345180   541.60 1984-06-01      NaT
# 36 -123.705680  2028.00 1984-10-04      NaT
# 37 -123.705680  2028.00 1984-10-04      NaT
# 28 -123.553000  1246.90 1990-08-30      NaT
# 27 -123.553000  1246.90 1990-08-30      NaT
# 43 -123.724960   850.00 1991-09-25      NaT
# 53 -123.923050    12.00 2001-10-23      NaT
# 51 -124.083370    12.00 2001-10-24      NaT
# 15 -123.755386   875.00 2002-05-12      NaT
# 16 -123.755386   875.00 2002-05-12      NaT
# 46 -123.924490     4.62 2004-01-30      NaT
# 58 -123.771180    45.00 2004-04-20      NaT
# 57 -123.771180    45.00 2004-04-20      NaT
# 54 -123.331902   162.00 2005-04-27      NaT
# 55 -123.331902   162.00 2005-04-27      NaT
# 10 -123.559100   327.00 2005-11-08      NaT
# 11 -123.559100   327.00 2005-11-08      NaT
# 29 -124.046220     4.29 2008-02-09      NaT
# 22 -123.563202    78.60 2009-01-08      NaT
# 21 -123.563202    78.60 2009-01-08      NaT
# 23 -123.504000   293.80 2009-08-27      NaT
# 24 -123.504000   293.80 2009-08-27      NaT
# 14 -124.566200    44.90 2009-11-18      NaT
# 13 -124.566200    44.90 2009-11-18      NaT
# 41 -123.798970   591.40 2011-01-20      NaT
# 40 -123.798970   591.40 2011-01-20      NaT
# 19 -124.049050   159.50 2011-08-09      NaT
# 18 -124.049050   159.50 2011-08-09      NaT
# 25 -124.053600    60.40 2015-01-29      NaT
# 35 -124.175440   741.00 2015-03-03      NaT
# 31 -124.159492     4.00 2015-03-04      NaT
# 3  -124.251380    62.00 2015-03-30      NaT
# 50 -124.287460     6.40 2015-04-01      NaT
# 8  -124.253340    34.00 2015-04-08      NaT
# 12 -124.109400    17.00 2015-04-08      NaT
# 56 -124.413300   184.60 2015-05-13      NaT
# 5  -124.563400    27.00 2015-06-24      NaT
# 2  -124.409300     6.50 2015-06-24      NaT
# 44 -123.822890    55.00 2015-07-24      NaT
# 9  -123.913600    46.00 2015-08-04      NaT
# 59 -124.096600   217.00 2015-08-13      NaT
# 7  -123.960500    13.00 2015-08-13      NaT
# 4  -124.293400   140.00 2015-08-26      NaT
# 26 -124.589100    18.00 2015-09-03      NaT
# 6  -123.978100    55.00 2015-09-17      NaT
# 45 -123.856900    68.00 2015-10-08      NaT
# 42 -124.107510     5.00 2015-11-12      NaT
# 34 -124.074870    34.00 2015-11-13      NaT
# 52 -123.830700    11.00 2015-11-13      NaT
# 39 -124.204503    36.00 2016-03-03      NaT
# 17 -123.498710  1605.00 2017-05-10      NaT
# 1  -123.789240   438.70 2018-06-13      NaT
# 0  -123.789240   438.70 2018-06-13      NaT

# %% [markdown]
# # Notes on preferred reference stations
# UW.JEDS..H[HN]?
# UW.BABR..H[HN]?
# UW.FISH..H[HN]?
# UW.LEBA..H[HN]?

# %%
inv_sub = client.get_stations(network='UW',station='JEDS,BABR,FISH,LEBA',
                              channel=CHAN_STR,level='response',
                              starttime=UTCDateTime(target_window[0].isoformat()),
                              endtime=UTCDateTime(target_window[1].isoformat()))
display(inv_sub)
# Out:
# Inventory created at 2023-11-16T23:06:06.138700Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2018-08-01...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			UW
# 		Stations (4):
# 			UW.BABR (Baber Butte, OR, USA)
# 			UW.FISH (Jewel, OR, USA)
# 			UW.JEDS (Smith River, Reedsport, OR, USA)
# 			UW.LEBA (Lebam, WA, USA)
# 		Channels (24):
# 			UW.BABR..ENZ, UW.BABR..ENN, UW.BABR..ENE, UW.BABR..HHZ,
# 			UW.BABR..HHN, UW.BABR..HHE, UW.FISH..ENZ, UW.FISH..ENN,
# 			UW.FISH..ENE, UW.FISH..HHZ, UW.FISH..HHN, UW.FISH..HHE,
# 			UW.JEDS..ENZ, UW.JEDS..ENN, UW.JEDS..ENE, UW.JEDS..HHZ,
# 			UW.JEDS..HHN, UW.JEDS..HHE, UW.LEBA..ENZ, UW.LEBA..ENN,
# 			UW.LEBA..ENE, UW.LEBA..HHZ, UW.LEBA..HHN, UW.LEBA..HHE

# %% [markdown]
# Possible lead on (re)training:
# https://shunya-vichar.medium.com/incremental-learning-in-xgboost-b3eac6135ce#:~:text=Update%20the%20model%3A%20XGBoost%20provides,based%20on%20the%20new%20information.
